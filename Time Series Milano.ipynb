# %%
import pandas as pd
import pylab as plt 
import seaborn as sns
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta
from math import sqrt
from matplotlib import pyplot as plt
from pmdarima import auto_arima
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.stattools import pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Function Definition

# %%
# The p_value is returned to verify Stationarity
def p_value(df_value):
    result = adfuller(df_value.dropna())
    print('ADF Statistic: %f' % result[0])
    print('p-value: {}'.format(result[1]))

# %%
# Correlation and Differencing Plots (1 e 2).
def Differencing_Plot(df_value):  
    
    fig, axes = plt.subplots(2, 2, figsize=(8, 8))
    axes[0, 0].plot(df_value)
    axes[0, 0].set_title('Original Series')
    plot_acf(df_value, ax=axes[0, 1])

    axes[1, 0].plot(df_value.diff())
    axes[1, 0].set_title('1st Order Differencing')
    plot_acf(df_value.diff().dropna(), ax=axes[1, 1])

    fig.tight_layout()
    return plt.show()

# %% [markdown]
# ## Creation of the New DataSet for Time Serie

# %%
Temperature = pd.read_csv('Temperature.csv')
Temperature
# Out:
#                  dt      City  Country  AverageTemperature  ANNO
# 0        1743-11-01     Århus  Denmark            6.068000  1743
# 1        1744-04-01     Århus  Denmark            5.788000  1744
# 2        1744-05-01     Århus  Denmark           10.644000  1744
# 3        1744-06-01     Århus  Denmark           14.051000  1744
# 4        1744-07-01     Århus  Denmark           16.082000  1744
# ...             ...       ...      ...                 ...   ...
# 8256236  2019-08-01  Cheyenne       US           21.555556  2019
# 8256237  2019-09-01  Cheyenne       US           22.888889  2019
# 8256238  2019-10-01  Cheyenne       US            7.055556  2019
# 8256239  2019-11-01  Cheyenne       US           -0.666667  2019
# 8256240  2019-12-01  Cheyenne       US           -3.500000  2019
#
# [8256241 rows x 5 columns]

# %%
Temperature.dtypes
# Out:
# dt                     object
# City                   object
# Country                object
# AverageTemperature    float64
# ANNO                    int64
# dtype: object

# %%
print(Temperature.isnull().sum())
# Out:
# dt                    0
# City                  0
# Country               0
# AverageTemperature    0
# ANNO                  0
# dtype: int64

# %%
#dt column type transformation
Temperature['dt']= pd.to_datetime(Temperature['dt'])

# %%
#selection of Milan data only
TempMi = Temperature.loc[(Temperature['City'] == 'Milan')]
TempMi.reset_index(inplace=True, drop=True)
TempMi
# Out:
#              dt   City Country  AverageTemperature  ANNO
# 0    1743-11-01  Milan   Italy            3.310000  1743
# 1    1744-04-01  Milan   Italy            7.226000  1744
# 2    1744-05-01  Milan   Italy            9.394000  1744
# 3    1744-06-01  Milan   Italy           13.216000  1744
# 4    1744-07-01  Milan   Italy           15.366000  1744
# ...         ...    ...     ...                 ...   ...
# 3233 2019-08-01  Milan   Italy           25.777778  2019
# 3234 2019-09-01  Milan   Italy           24.500000  2019
# 3235 2019-10-01  Milan   Italy           18.944444  2019
# 3236 2019-11-01  Milan   Italy           11.555556  2019
# 3237 2019-12-01  Milan   Italy            6.722222  2019
#
# [3238 rows x 5 columns]

# %%
#Preparation to display the time series
TempMi1= TempMi[['dt','AverageTemperature']]
TempMi1.set_index('dt', inplace = True)
TempMi1
# Out:
#             AverageTemperature
# dt
# 1743-11-01            3.310000
# 1744-04-01            7.226000
# 1744-05-01            9.394000
# 1744-06-01           13.216000
# 1744-07-01           15.366000
# ...                        ...
# 2019-08-01           25.777778
# 2019-09-01           24.500000
# 2019-10-01           18.944444
# 2019-11-01           11.555556
# 2019-12-01            6.722222
#
# [3238 rows x 1 columns]

# %% [markdown]
# # Time Series

# %%
TempMi1['AverageTemperature'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='dt'>

# %%
#selection only a few years
interval_year = (TempMi['ANNO'] > 1989) & (TempMi['ANNO'] <2020)
TempMi2 = TempMi.loc[interval_year]
TempMi2
# Out:
#              dt   City Country  AverageTemperature  ANNO
# 2882 1990-01-01  Milan   Italy           -1.209000  1990
# 2883 1990-02-01  Milan   Italy            3.072000  1990
# 2884 1990-03-01  Milan   Italy            5.432000  1990
# 2885 1990-04-01  Milan   Italy            5.399000  1990
# 2886 1990-05-01  Milan   Italy           12.617000  1990
# ...         ...    ...     ...                 ...   ...
# 3233 2019-08-01  Milan   Italy           25.777778  2019
# 3234 2019-09-01  Milan   Italy           24.500000  2019
# 3235 2019-10-01  Milan   Italy           18.944444  2019
# 3236 2019-11-01  Milan   Italy           11.555556  2019
# 3237 2019-12-01  Milan   Italy            6.722222  2019
#
# [356 rows x 5 columns]

# %%
#Preparation to display the time series
TempMi2= TempMi2[['dt','AverageTemperature']]
TempMi2.set_index('dt', inplace = True)
TempMi2
# Out:
#             AverageTemperature
# dt
# 1990-01-01           -1.209000
# 1990-02-01            3.072000
# 1990-03-01            5.432000
# 1990-04-01            5.399000
# 1990-05-01           12.617000
# ...                        ...
# 2019-08-01           25.777778
# 2019-09-01           24.500000
# 2019-10-01           18.944444
# 2019-11-01           11.555556
# 2019-12-01            6.722222
#
# [356 rows x 1 columns]

# %%
TempMi2['AverageTemperature'].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='dt'>

# %% [markdown]
# ## Seasonality

# %% [markdown]
# Seasonality in time-series data refers to a pattern that occurs at a regular interval.

# %% [markdown]
# ### Additive Seasonal Decompose

# %%
# Seasonal Variation Analyzing
plt.rcParams.update({'figure.figsize': (8,8)})
result_add = seasonal_decompose(TempMi2['AverageTemperature'], model = 'additive', period = 40)
decomposition_result = result_add.plot()

# %% [markdown]
# ## Stationarity

# %% [markdown]
# A stationary time series is a series whose statistical properties are independent of the point in time at which they are observed. This Means that Mean, variance and other statistics of a stationary time series remains constant.
# The p-value represents a probability of the error when expecting, that the trend differs from zero. Returning p_value to verify Stationarity.

# %%
# ADF calculation
p_value(TempMi2['AverageTemperature'])
# Out:
# ADF Statistic: -0.485543
# p-value: 0.894806887709539

# %% [markdown]
# ### Differencing

# %% [markdown]
# Differencing can help stabilize the mean of the time series by removing changes in the level of a time series, and so eliminating (or reducing) Trend and Seasonality.

# %%
# Differencing plots representation
Differencing_Plot(TempMi2['AverageTemperature'])

# %%
p_value(TempMi2['AverageTemperature'].diff())
# Out:
# ADF Statistic: -7.327807
# p-value: 1.1487201498001998e-10

# %% [markdown]
# ### Showing Autocorrelation Coefficents

# %%
lag_acf= acf(TempMi2, nlags = 140)
lag_pacf= pacf(TempMi2, nlags = 70)
fig, ax = plt.subplots(1,2,figsize =(20,5))
plot_acf(lag_acf, ax=ax[0])
plot_pacf(lag_pacf, lags=20, ax=ax[1])
plt.show()

# %% [markdown]
# ## Model Creation

# %%
# Finding best p and q for the analysis

def findBestComposition(train, test):
    vMax = 3
    ps = []
    qs = []
    vs = []
    best_p = 0
    best_q = 0
    bestValue = None
    history = [x for x in train]
    predictions = []
    
    # Trying p from 0 to 2
    for p in range(vMax):
        # Trying q from 0 to 2
        for q in range(vMax):
            history = [x for x in train]
            predictions = []
            
            # Generating SARIMA model with specific p and q
            for t in range(len(test)):
                model = SARIMAX(history, order=(p,1,q), seasonal_order=(0, 1, 0, 12))
                model_fit = model.fit()
                output = model_fit.forecast()
                yhat = output[0]
                predictions.append(yhat)
                obs = test[t]
                history.append(obs)
                
            # Computing RMSE for the generated Model
            rmse = sqrt(mean_squared_error(test, predictions))
            if bestValue is None or rmse < bestValue:
                bestValue = rmse
                best_p = p
                best_q = q
            ps.append(p)
            qs.append(q)
            vs.append(rmse)
            
    # Creating a df containing RMSE for each p and q composition
    data = pd.DataFrame({'P': ps, 'Q': qs, 'RMSE': vs})
    return data.pivot('P', 'Q', 'RMSE'), bestValue, best_p, best_q

# %%
# Creating the model for the specific DF

def generateModel(analysis_df, title):
    
    # DF Manipulation
    df = analysis_df.copy()
    
    # Creating Train and Test set
    X = df.values
    size = int(len(X) * 0.75)
    train, test = X[0:size], X[size:len(X)]
    
    # Finding best p and q
    data_pivoted, rsme, p ,q = findBestComposition(train, test)
    
    history = [x for x in train]
    predictions = []
    
    # Creating SARIMA Model
    for t in range(len(test)):
        model = SARIMAX(history, order=(p,1,q), seasonal_order=(0, 1, 0, 12))
        model_fit = model.fit()
        output = model_fit.forecast()
        yhat = output[0]
        predictions.append(yhat)
        obs = test[t]
        history.append(obs)
    
    # Computing RMSE with model results
    rmse = sqrt(mean_squared_error(test, predictions))
    
    array = df.index.values
    assex = []
    for i in range(len(df.index)-len(test), len(df.index)):
        assex.append(array[i])
    
    # Plotting Heatmap with p and q composition
    ax = sns.heatmap(data_pivoted, cmap="coolwarm")
    ax.set_title('Best RMSE:{0} with p:{1} q:{2}'.format(int(rsme), p, q))
    plt.show()
    
    # Plotting real and predicted data
    fig, ax = plt.subplots(figsize=(15,5))
    plt.plot(assex, test, label='Test Data')
    plt.title(title.format(int(rsme), p, q))
    plt.plot(assex, predictions, color='orange', label='Predicted Data')
    ax.legend()
    plt.show()
    
    
    # Predicting Future Data from 2020 to 2021
    start = datetime.strptime("2020-01-01", "%Y-%m-%d")
    date_list = [start + relativedelta(months=x) for x in range(0,12)]
    future = pd.DataFrame(index=date_list, columns= df.columns)
    future['events'] = model_fit.predict(start = len(df), end = len(df)+11, dynamic= True)
    
    # Ploting Future Data from 2020 to 2021
    fig, ax = plt.subplots(figsize=(15,5))
    chart = sns.lineplot(data = future['events'], palette=['blue'])
    chart.set_title('Forcasted Data for '+title)

# %%
# Generating Model

generateModel(TempMi2, 'Milano')

# %%
################################################################################################################################

# %%
# Dynamic function to divide Dataset into testing and training set 
def Dynamic_Splitting (parDf,parColumn,parTrainSize):
    
    # Test e Train DataSet creation
    train_size = parTrainSize
    split_idx = round(len(TempMi2["AverageTemperature"])* train_size)

    # Split
    train = TempMi2.iloc[:split_idx]
    test = TempMi2.iloc[split_idx:]
    

    # Visualize split
    fig,ax= plt.subplots(figsize=(10,10))
    kws = dict(marker='o')
    plt.plot(train, label='Train', **kws)
    plt.plot(test, label='Test', **kws)
    ax.legend(bbox_to_anchor=[1,1]);
    
    return train, test

# %%
train, test = Dynamic_Splitting(TempMi2,"AverageTemperature",0.75)

# %% [markdown]
# ## LSTM Forecasting

# %% [markdown]
# LSTM allows to predict the future values of a Time Serie adopting a Machine Learning approach

# %% [markdown]
# Before to start Training and Testing data are scaled. Here the minimum value n the dataset is subtracted of the features, then the elements into the dataset are divided from the Range (Max Value - Min Value)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
TempMi2.head(),TempMi2.tail()
# Out:
# (            AverageTemperature
#  dt
#  1990-01-01              -1.209
#  1990-02-01               3.072
#  1990-03-01               5.432
#  1990-04-01               5.399
#  1990-05-01              12.617,
#              AverageTemperature
#  dt
#  2019-08-01           25.777778
#  2019-09-01           24.500000
#  2019-10-01           18.944444
#  2019-11-01           11.555556
#  2019-12-01            6.722222)

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
scaled_train[:10]
# Out:
# array([[0.10575116],
#        [0.28061433],
#        [0.37701168],
#        [0.37566375],
#        [0.67049261],
#        [0.72604362],
#        [0.86716772],
#        [0.86267462],
#        [0.68266481],
#        [0.53835471]])

# %%
# Generator Definition for 12 month
from keras.preprocessing.sequence import TimeseriesGenerator

n_input = 12
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length = n_input, batch_size = 1)

# %%
X,y = generator[0]
print(f'Array: \n{X.flatten()}')
print(f'Prediction: \n{y}')
# Out:
# Array:
# [0.10575116 0.28061433 0.37701168 0.37566375 0.67049261 0.72604362
#  0.86716772 0.86267462 0.68266481 0.53835471 0.24569071 0.03810963]
# Prediction:
# [[0.0947635]]

# %%
X.shape  #N_Rows, N_Columns, N_Features
# Out:
# (1, 12, 1)

# %% [markdown]
# ## LSTM Model Implementation

# %% [markdown]
# At this point the LSTM model can be defined. Activation and Loss Functions are required, where the first has 'tanh' as default value, but in this case ReLU function is preferred to guarantee better quality to the neural unit (bounded, monotony, easy to handle)

# %%
# Model Definition
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

model = Sequential()
model.add(LSTM(100, activation = 'relu', input_shape = (n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer = 'adam', loss = 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 100)               40800
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(generator,epochs=50)
# Out:
# Epoch 1/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0790
# Epoch 2/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0223
# Epoch 3/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0090
# Epoch 4/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0072
# Epoch 5/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0065
# Epoch 6/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0067
# Epoch 7/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0070
# Epoch 8/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0073
# Epoch 9/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0057
# Epoch 10/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0062
# Epoch 11/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0059
# Epoch 12/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0063
# Epoch 13/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0057
# Epoch 14/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0060
# Epoch 15/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0067
# Epoch 16/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0065
# Epoch 17/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0058
# Epoch 18/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0061
# Epoch 19/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0062
# Epoch 20/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0053
# Epoch 21/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0068
# Epoch 22/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 23/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0051
# Epoch 24/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 25/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0058
# Epoch 26/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 27/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0050
# Epoch 28/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0063
# Epoch 29/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0051
# Epoch 30/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 31/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0053
# Epoch 32/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0050
# Epoch 33/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 34/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0048
# Epoch 35/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0055
# Epoch 36/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0048
# Epoch 37/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0056
# Epoch 38/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0052
# Epoch 39/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0049
# Epoch 40/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0051
# Epoch 41/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0050
# Epoch 42/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0049
# Epoch 43/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0051
# Epoch 44/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0054
# Epoch 45/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0050
# Epoch 46/50
# 255/255 [==============================] - 1s 3ms/step - loss: 0.0052
# Epoch 47/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0051
# Epoch 48/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0049
# Epoch 49/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0049
# Epoch 50/50
# 255/255 [==============================] - 1s 2ms/step - loss: 0.0049

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
last_train_batch = scaled_train[-12:]

# %%
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# 1/1 [==============================] - 0s 95ms/step
# array([[0.5177288]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.41536639])

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 0s/step
# 1/1 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 4ms/step

# %%
test_predictions
# Out:
# [array([0.5177288], dtype=float32),
#  array([0.65197426], dtype=float32),
#  array([0.76402855], dtype=float32),
#  array([0.8433511], dtype=float32),
#  array([0.85890514], dtype=float32),
#  array([0.72867024], dtype=float32),
#  array([0.4899864], dtype=float32),
#  array([0.2938918], dtype=float32),
#  array([0.14415304], dtype=float32),
#  array([0.12458085], dtype=float32),
#  array([0.2094275], dtype=float32),
#  array([0.35090888], dtype=float32),
#  array([0.50355583], dtype=float32),
#  array([0.64585626], dtype=float32),
#  array([0.761151], dtype=float32),
#  array([0.8336866], dtype=float32),
#  array([0.8266798], dtype=float32),
#  array([0.6863672], dtype=float32),
#  array([0.45815882], dtype=float32),
#  array([0.26594046], dtype=float32),
#  array([0.13008758], dtype=float32),
#  array([0.1287351], dtype=float32),
#  array([0.19061475], dtype=float32),
#  array([0.3465585], dtype=float32),
#  array([0.5077984], dtype=float32),
#  array([0.65170324], dtype=float32),
#  array([0.766301], dtype=float32),
#  array([0.83274937], dtype=float32),
#  array([0.81325126], dtype=float32),
#  array([0.66173613], dtype=float32),
#  array([0.4361128], dtype=float32),
#  array([0.2515226], dtype=float32),
#  array([0.12694027], dtype=float32),
#  array([0.12974513], dtype=float32),
#  array([0.1971505], dtype=float32),
#  array([0.3557415], dtype=float32),
#  array([0.51810676], dtype=float32),
#  array([0.660664], dtype=float32),
#  array([0.7725781], dtype=float32),
#  array([0.83310866], dtype=float32),
#  array([0.80295247], dtype=float32),
#  array([0.64165616], dtype=float32),
#  array([0.41724524], dtype=float32),
#  array([0.23841098], dtype=float32),
#  array([0.12419055], dtype=float32),
#  array([0.13286228], dtype=float32),
#  array([0.20795316], dtype=float32),
#  array([0.36815396], dtype=float32),
#  array([0.53011376], dtype=float32),
#  array([0.6703848], dtype=float32),
#  array([0.7790025], dtype=float32),
#  array([0.8334823], dtype=float32),
#  array([0.793059], dtype=float32),
#  array([0.62298405], dtype=float32),
#  array([0.3998227], dtype=float32),
#  array([0.22488612], dtype=float32),
#  array([0.12179214], dtype=float32),
#  array([0.13569249], dtype=float32),
#  array([0.21975589], dtype=float32),
#  array([0.38123497], dtype=float32),
#  array([0.5424598], dtype=float32),
#  array([0.6803962], dtype=float32),
#  array([0.7854761], dtype=float32),
#  array([0.8337585], dtype=float32),
#  array([0.78317875], dtype=float32),
#  array([0.60517573], dtype=float32),
#  array([0.38307494], dtype=float32),
#  array([0.21201338], dtype=float32),
#  array([0.11990055], dtype=float32),
#  array([0.13862301], dtype=float32),
#  array([0.2324011], dtype=float32),
#  array([0.39485118], dtype=float32),
#  array([0.5548348], dtype=float32),
#  array([0.69048095], dtype=float32),
#  array([0.79182833], dtype=float32),
#  array([0.833717], dtype=float32),
#  array([0.77293086], dtype=float32),
#  array([0.5874232], dtype=float32),
#  array([0.36683604], dtype=float32),
#  array([0.19976455], dtype=float32),
#  array([0.1188169], dtype=float32),
#  array([0.14191656], dtype=float32),
#  array([0.24517688], dtype=float32),
#  array([0.4085187], dtype=float32),
#  array([0.5670408], dtype=float32),
#  array([0.7004609], dtype=float32),
#  array([0.7979489], dtype=float32),
#  array([0.8332171], dtype=float32),
#  array([0.7620071], dtype=float32)]

# %%
test.head()
# Out:
#             AverageTemperature
# dt
# 2012-04-01               6.371
# 2012-05-01              11.883
# 2012-06-01              15.454
# 2012-07-01              17.262
# 2012-08-01              18.409

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot:xlabel='dt'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(test['AverageTemperature'],test['Predictions']))
print(rmse)
# Out:
# 10.740245291553702
