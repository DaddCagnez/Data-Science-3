# %%
import pandas as pd
import pylab as plt 
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #  Milano & Roma Average Temperaturet analysis and Time Series forecasting

# %% [markdown]
# # Goal
# due righe sugli obbettivi...

# %% [markdown]
# # Preanalysis
# In this first phase, i wanted to conduct an analysis to obtain information on datasets related to the average temperatures of different cities.
# So i merged the two datasets by removing the null values and taking only the columns useful for analysis

# %%
Landtemperture = pd.read_csv('GlobalLandTemperaturesByCity.csv')
Landtemperture.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
Citytempereture = pd.read_csv('city_temperature.csv')
Citytempereture.head()
# Out:
#    Region  Country State     City  Month  Day  Year  AvgTemperature
# 0  Africa  Algeria   NaN  Algiers      1    1  1995            64.2
# 1  Africa  Algeria   NaN  Algiers      1    2  1995            49.4
# 2  Africa  Algeria   NaN  Algiers      1    3  1995            48.8
# 3  Africa  Algeria   NaN  Algiers      1    4  1995            46.4
# 4  Africa  Algeria   NaN  Algiers      1    5  1995            47.9

# %%
import pandas as pd
import pylab as plt 
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go

# %% [markdown]
# # Analysis
# The analysis phase includes the analysis of the two separate datasets first generally and then for the cities of Milan and Rome

# %% [markdown]
# ![Grafico%20a%20torta%20generale-2.png](attachment:Grafico%20a%20torta%20generale-2.png)

# %% [markdown]
# # First dataset graphs

# %% [markdown]
# # Highest temperatures by state

# %% [markdown]
# ![Temperature%20max%20per%20stato%20gradi%20%281%29-2.png](attachment:Temperature%20max%20per%20stato%20gradi%20%281%29-2.png)

# %% [markdown]
# ![Temperature%20max%20per%20stato%20%281%29.png](attachment:Temperature%20max%20per%20stato%20%281%29.png)

# %% [markdown]
# # Lowest temperatures by state

# %% [markdown]
# ![Temperature%20min%20per%20stato%20gradi%20%281%29.png](attachment:Temperature%20min%20per%20stato%20gradi%20%281%29.png)

# %% [markdown]
# ![Temperature%20min%20per%20stato%20%281%29-3.png](attachment:Temperature%20min%20per%20stato%20%281%29-3.png)

# %% [markdown]
# # Highest temperatures by city

# %% [markdown]
# ![Temperature%20max%20per%20citt%C3%A0%20gradi%20%281%29.png](attachment:Temperature%20max%20per%20citt%C3%A0%20gradi%20%281%29.png)

# %% [markdown]
# ![Temperature%20max%20per%20citt%C3%A0%20%281%29.png](attachment:Temperature%20max%20per%20citt%C3%A0%20%281%29.png)

# %% [markdown]
# # Lowest temperatures by city

# %% [markdown]
# ![Temperature%20min%20per%20citt%C3%A0%20gradi%20%281%29.png](attachment:Temperature%20min%20per%20citt%C3%A0%20gradi%20%281%29.png)

# %% [markdown]
# ![Temperature%20min%20per%20citt%C3%A0%20%281%29.png](attachment:Temperature%20min%20per%20citt%C3%A0%20%281%29.png)

# %% [markdown]
# # Years with the highest temperatures (1700 to 1900)

# %% [markdown]
# ![Anni%20massimi%201700%201900%20gradi.png](attachment:Anni%20massimi%201700%201900%20gradi.png)

# %% [markdown]
# ![Anni%20massimi%201700%201900.png](attachment:Anni%20massimi%201700%201900.png)

# %% [markdown]
# # Years with the lowest temperatures (1700 to 1900)

# %% [markdown]
# ![Anni%20minimi%201700%201900%20gradi.png](attachment:Anni%20minimi%201700%201900%20gradi.png)

# %% [markdown]
# ![Anni%20minimi%201700%201900.png](attachment:Anni%20minimi%201700%201900.png)

# %% [markdown]
# # Years with the highest temperatures (1900 to 2014)

# %% [markdown]
# ![Anni%20massimi%201900%202014%20gradi.png](attachment:Anni%20massimi%201900%202014%20gradi.png)

# %% [markdown]
# ![Anni%20massimi%201900%202014.png](attachment:Anni%20massimi%201900%202014.png)

# %% [markdown]
# # Years with the lowest temperatures (1900 to 2014)

# %% [markdown]
# ![Anni%20minimi%201900%202014%20gradi.png](attachment:Anni%20minimi%201900%202014%20gradi.png)

# %% [markdown]
# ![Anni%20minimi%201900%202014.png](attachment:Anni%20minimi%201900%202014.png)

# %% [markdown]
# ### Italy
# ![Grafico%20a%20torta%20italia-2.png](attachment:Grafico%20a%20torta%20italia-2.png)

# %% [markdown]
# ### Maximum temperatures by Italian city
# ![Temperature%20max%20per%20citt%C3%A0%20italiane%20%281%29.png](attachment:Temperature%20max%20per%20citt%C3%A0%20italiane%20%281%29.png)

# %% [markdown]
# ### Minimum temperatures by Italian city
# ![Temperature%20min%20per%20citt%C3%A0%20italiane%20%281%29.png](attachment:Temperature%20min%20per%20citt%C3%A0%20italiane%20%281%29.png)

# %% [markdown]
# ### Boxplot Milano
# ![Boxplot%20milano%20%281%29.png](attachment:Boxplot%20milano%20%281%29.png)

# %% [markdown]
# ### Boxplot Roma
# ![Boxplot%20roma%20%281%29.png](attachment:Boxplot%20roma%20%281%29.png)

# %% [markdown]
# # Second dataset graphs

# %% [markdown]
# # Highest temperatures by state

# %% [markdown]
# ![Temperature%20max%20per%20stato%20gradi%20%282%29.png](attachment:Temperature%20max%20per%20stato%20gradi%20%282%29.png)

# %% [markdown]
# ![Temperature%20max%20per%20stato%20%282%29.png](attachment:Temperature%20max%20per%20stato%20%282%29.png)

# %% [markdown]
# # Lowest temperatures by state
# Unfortunately, the data were poorly collected so I will not show these graphs
# Fortunately, this poor data collection does not affect Milan and Rome

# %% [markdown]
# # Highest temperatures by city

# %% [markdown]
# ![Temperature%20max%20per%20citt%C3%A0%20gradi%20%282%29.png](attachment:Temperature%20max%20per%20citt%C3%A0%20gradi%20%282%29.png)

# %% [markdown]
# ![Temperature%20max%20per%20citt%C3%A0%20%282%29.png](attachment:Temperature%20max%20per%20citt%C3%A0%20%282%29.png)

# %% [markdown]
# # Years with the highest temperatures (2014 to 2020)

# %% [markdown]
# ![Anni%20massimi%202014%202019%20gradi.png](attachment:Anni%20massimi%202014%202019%20gradi.png)

# %% [markdown]
# ![Anni%20massimi%202014%202019.png](attachment:Anni%20massimi%202014%202019.png)

# %% [markdown]
# ### Italy
# ![Grafico%20a%20torta%20Milano%20Roma.png](attachment:Grafico%20a%20torta%20Milano%20Roma.png)

# %% [markdown]
# ### Maximum temperatures by Italian city
# ![Temperature%20max%20Milano%20Roma-2.png](attachment:Temperature%20max%20Milano%20Roma-2.png)

# %% [markdown]
# ### Minimum temperatures by Italian city
# ![Temperature%20min%20Milano%20Roma.png](attachment:Temperature%20min%20Milano%20Roma.png)

# %% [markdown]
# ### Boxplot Milano
# ![Boxplot%20milano%20%282%29.png](attachment:Boxplot%20milano%20%282%29.png)

# %% [markdown]
# ### Boxplot Roma
# ![Boxplot%20roma%20%282%29.png](attachment:Boxplot%20roma%20%282%29.png)

# %% [markdown]
# # Time Series analysis and forecasting
#
# Time series analysis is a specific way of analyzing a sequence of data points collected over an interval of time, where data points are recorded at consistent intervals over a set period of time rather than just recording the data points intermittently or randomly. One of the primary purposes of the time series analysis consists in understanding the seasonal trends and stationarity and how they change over time.
# In the second part of the project we studied the predictions made by a statistical model and a Machine Learning model.

# %% [markdown]
# #### SARIMAX model
# SARIMAX is an autoregressive statistical model, which can predict future data using past ones. In order to implement the Sarimax prediction model, we have to find out the optimal model. For this reason, we have used Auto_Arima to discover the best configuration.

# %% [markdown]
# #### LSTM forecasting
# LSTM Forecasting allows to predict the future values of a Time Serie adopting a Machine Learning approach.
# Before starting we have scaled Training and Testing data, where the minimum value n the dataset is subtracted of the features, then the elements into the dataset are divided from the Range (Max Value - Min Value)

# %% [markdown]
# ## Seasonality
# Seasonality is a characteristic of a time series in which the data experiences regular and predictable changes that recur every calendar year. Any predictable fluctuation or pattern that recurs or repeats over a one-year period is said to be seasonal.

# %% [markdown]
# ## Stationarity
# A stationary time series is a series whose statistical properties are independent of the point in time at which they are observed. This Means that Mean, variance and other statistics of a stationary time series remains constant.

# %% [markdown]
# # TimeSeries Hired Milano

# %% [markdown]
# Da inserire file timeseries

# %% [markdown]
# # TimeSeries Hired Roma

# %% [markdown]
# Da inserire file timeseries

# %% [markdown]
# # Conclusions
# inserisco conclusioni

# %% [markdown]
# # Thanks for your attention
# <font color= blue> CAGNETTA DAVIDE 732521</font>
